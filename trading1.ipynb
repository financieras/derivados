# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/derivados2022/blob/main/trading1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ESTRATEGIAS DE TRADING CON PYTHON
# ## Librería TA-Lib: Technical Analysis Library
# Utilizaremos la librería TA-Lib

# %%
# !pip install talib-binary   # para cargar la librería TA-Lib en el entorno de Colab
# Out:
# Collecting talib-binary
#   Downloading talib_binary-0.4.19-cp37-cp37m-manylinux1_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 7.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from talib-binary) (1.21.5)
# Installing collected packages: talib-binary
# Successfully installed talib-binary-0.4.19

# %%
pip install yfinance       # para cargar la librería de Yahoo finance en el entorno de Colab
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)

# %%
import talib as ta                # importamos la librería con el alias ta
import matplotlib.pyplot as plt   # importamos pyplot de la librería matplotlib con el alias plt
import yfinance as yf             # importamos la librería de Yahoo finance con el alias yf

# %%
msft = yf.Ticker("MSFT")

# Obtener información de mercado de un ticker concreto
msft.info         # información sobre Microsoft Corporation
# Out:
# {'52WeekChange': 0.2816149,
#  'SandP52WeekChange': 0.12741053,
#  'address1': 'One Microsoft Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 298.57,
#  'askSize': 900,
#  'averageDailyVolume10Day': 35022170,
#  'averageVolume': 37167255,
#  'averageVolume10days': 35022170,
#  'beta': 0.910925,
#  'beta3Year': None,
#  'bid': 298.53,
#  'bidSize': 900,
#  'bookValue': 21.335,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Redmond',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 298.805,
#  'currentRatio': 2.247,
#  'dateShortInterest': 1646006400,
#  'dayHigh': 298.97,
#  'dayLow': 292.73,
#  'debtToEquity': 50.217,
#  'dividendRate': 2.48,
#  'dividendYield': 0.0089,
#  'earningsGrowth': 0.222,
#  'earningsQuarterlyGrowth': 0.214,
#  'ebitda': 90829996032,
#  'ebitdaMargins': 0.49123,
#  'enterpriseToEbitda': 23.871,
#  'enterpriseToRevenue': 11.726,
#  'enterpriseValue': 2168229855232,
#  'exDividendDate': 1652832000,
#  'exchange': 'NMS',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'expireDate': None,
#  'fiftyDayAverage': 298.5996,
#  'fiftyTwoWeekHigh': 349.67,
#  'fiftyTwoWeekLow': 229.35,
#  'financialCurrency': 'USD',
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 1.34,
#  'floatShares': 7489894342,
#  'forwardEps': 10.75,
#  'forwardPE': 27.795813,
#  'freeCashflow': 46479876096,
#  'fromCurrency': None,
#  'fullTimeEmployees': 181000,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '-14400000',
#  'grossMargins': 0.68825996,
#  'grossProfits': 115856000000,
#  'heldPercentInsiders': 0.00059,
#  'heldPercentInstitutions': 0.71933,
#  'impliedSharesOutstanding': 0,
#  'industry': 'Software—Infrastructure',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1652832000,
#  'lastDividendValue': 0.62,
#  'lastFiscalYearEnd': 1625011200,
#  'lastMarket': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com',
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. Its Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. Its Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also offers support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. Its More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. It sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. It has collaborations with Dynatrace, Inc., Morgan Stanley, Micro Focus, WPP plc, ACI Worldwide, Inc., and iCIMS, Inc., as well as strategic relationships with Avaya Holdings Corp. and wejo Limited. Microsoft Corporation was founded in 1975 and is based in Redmond, Washington.',
#  'longName': 'Microsoft Corporation',
#  'market': 'us_market',
#  'marketCap': 2240102268928,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_21835',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1640908800,
#  'navPrice': None,
#  'netIncomeToCommon': 71184998400,
#  'nextFiscalYearEnd': 1688083200,
#  'numberOfAnalystOpinions': 46,
#  'open': 295.37,
#  'openInterest': None,
#  'operatingCashflow': 83909001216,
#  'operatingMargins': 0.42523998,
#  'payoutRatio': 0.2449,
#  'pegRatio': 1.81,
#  'phone': '425 882 8080',
#  'preMarketPrice': 294.09,
#  'previousClose': 295.22,
#  'priceHint': 2,
#  'priceToBook': 14.00539,
#  'priceToSalesTrailing12Months': 12.115014,
#  'profitMargins': 0.38498002,
#  'quickRatio': 2.05,
#  'quoteType': 'EQUITY',
#  'recommendationKey': 'buy',
#  'recommendationMean': 1.7,
#  'regularMarketDayHigh': 298.97,
#  'regularMarketDayLow': 292.73,
#  'regularMarketOpen': 295.37,
#  'regularMarketPreviousClose': 295.22,
#  'regularMarketPrice': 298.805,
#  'regularMarketVolume': 23389199,
#  'returnOnAssets': 0.15248999,
#  'returnOnEquity': 0.49051,
#  'revenueGrowth': 0.201,
#  'revenuePerShare': 24.585,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Technology',
#  'sharesOutstanding': 7496869888,
#  'sharesPercentSharesOut': 0.0055,
#  'sharesShort': 41488998,
#  'sharesShortPreviousMonthDate': 1643587200,
#  'sharesShortPriorMonth': 40179258,
#  'shortName': 'Microsoft Corporation',
#  'shortPercentOfFloat': 0.0055,
#  'shortRatio': 1.1,
#  'startDate': None,
#  'state': 'WA',
#  'strikePrice': None,
#  'symbol': 'MSFT',
#  'targetHighPrice': 425,
#  'targetLowPrice': 306.55,
#  'targetMeanPrice': 370.89,
#  'targetMedianPrice': 370,
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'totalCash': 125348003840,
#  'totalCashPerShare': 16.72,
#  'totalDebt': 80353001472,
#  'totalRevenue': 184902991872,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 2.36,
#  'trailingAnnualDividendYield': 0.007994038,
#  'trailingEps': 9.389,
#  'trailingPE': 31.825006,
#  'trailingPegRatio': 1.9338,
#  'twoHundredDayAverage': 300.83856,
#  'volume': 23389199,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'https://www.microsoft.com',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': '98052-6399'}

# %%
# get historical market data
hist = msft.history(period="max")
print(hist)
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055949    0.064177    0.055949    0.061434  1031788800
# 1986-03-14    0.061434    0.064725    0.061434    0.063628   308160000
# 1986-03-17    0.063628    0.065274    0.063628    0.064725   133171200
# 1986-03-18    0.064725    0.065274    0.062531    0.063079    67766400
# 1986-03-19    0.063079    0.063628    0.061434    0.061982    47894400
# ...                ...         ...         ...         ...         ...
# 2022-03-14  280.339996  285.399994  275.820007  276.440002    30660700
# 2022-03-15  280.350006  287.820007  278.730011  287.149994    34245100
# 2022-03-16  289.109985  294.570007  283.200012  294.390015    37826300
# 2022-03-17  293.290009  295.609985  289.369995  295.220001    30791300
# 2022-03-18  295.369995  299.000000  292.730011  298.989990    23570140
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# 1986-03-14        0.0           0.0
# 1986-03-17        0.0           0.0
# 1986-03-18        0.0           0.0
# 1986-03-19        0.0           0.0
# ...               ...           ...
# 2022-03-14        0.0           0.0
# 2022-03-15        0.0           0.0
# 2022-03-16        0.0           0.0
# 2022-03-17        0.0           0.0
# 2022-03-18        0.0           0.0
#
# [9079 rows x 7 columns]

# %%
# show news
msft.news
# Out:
# [{'link': 'https://finance.yahoo.com/news/why-microsofts-dividend-growth-still-173010142.html',
#   'providerPublishTime': 1647624610,
#   'publisher': 'GuruFocus.com',
#   'title': "Why Microsoft's Dividend Growth Is Still In the Early Innings",
#   'type': 'STORY',
#   'uuid': 'ea74ed95-2bda-3f23-ae28-bb0e7ae8d519'},
#  {'link': 'https://finance.yahoo.com/news/thinking-trading-options-stock-nvidia-151400429.html',
#   'providerPublishTime': 1647616440,
#   'publisher': 'PR Newswire',
#   'title': 'Thinking about trading options or stock in NVIDIA, Alibaba, Microsoft, Exxon Mobil, or Cisco Systems?',
#   'type': 'STORY',
#   'uuid': '006da378-dc98-3cdc-8c6d-a2823c398799'},
#  {'link': 'https://finance.yahoo.com/m/b4b9d73b-72a8-3058-b27a-ea280cb71c5b/microsoft-ads-in-windows.html',
#   'providerPublishTime': 1647613231,
#   'publisher': 'Investopedia',
#   'title': 'Microsoft Ads in Windows Could Drive Product Adoption',
#   'type': 'STORY',
#   'uuid': 'b4b9d73b-72a8-3058-b27a-ea280cb71c5b'},
#  {'link': 'https://finance.yahoo.com/news/rogers-communications-rci-microsoft-inks-131001084.html',
#   'providerPublishTime': 1647609001,
#   'publisher': 'Zacks',
#   'title': 'Rogers Communications (RCI)-Microsoft Inks Deal, Focus on Digitization',
#   'type': 'STORY',
#   'uuid': 'd72f2d13-0be5-3898-b3e2-13b87c46e182'},
#  {'link': 'https://finance.yahoo.com/news/why-buy-cybersecurity-stocks-etfs-201208771.html',
#   'providerPublishTime': 1647547928,
#   'publisher': 'Zacks',
#   'title': 'Why You Should Buy Cybersecurity Stocks & ETFs Now',
#   'type': 'STORY',
#   'uuid': 'e17e3568-0148-3cff-a751-f4a94c67cc8d'},
#  {'link': 'https://finance.yahoo.com/video/russia-ukraine-war-keeps-away-200609309.html',
#   'providerPublishTime': 1647547569,
#   'publisher': 'Yahoo Finance Video',
#   'title': 'Russia-Ukraine war ‘keeps me away from going all-in’ on tech stocks, portfolio manager says',
#   'type': 'VIDEO',
#   'uuid': '711c40bf-5193-3017-b9f8-b2df54205803'},
#  {'link': 'https://finance.yahoo.com/video/stocks-turn-higher-oil-biggest-192418632.html',
#   'providerPublishTime': 1647545058,
#   'publisher': 'Yahoo Finance Video',
#   'title': 'Stocks turn higher, oil has biggest day since November 2020',
#   'type': 'VIDEO',
#   'uuid': 'd7da2d11-77fc-3549-9508-070b9be51cda'},
#  {'link': 'https://finance.yahoo.com/news/buy-oversold-tech-stocks-especially-apple-analyst-171303333.html',
#   'providerPublishTime': 1647537183,
#   'publisher': 'Yahoo Finance',
#   'title': 'Buy ‘oversold tech stocks,’ especially Apple: Analyst',
#   'type': 'STORY',
#   'uuid': '82ecea4b-bf92-46e4-bccb-3d1627a1c979'}]

# %%
# mostrar los resultados
msft.earnings
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
# mostrar los resultados trimestrales
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000
# 3Q2021   45317000000  20505000000
# 4Q2021   51728000000  18765000000

# %% [markdown]
# ### Ejercicio
# * Buscar el ticker de Starbucks.
# * Pedir que se muestren los resultados trimestrales de Starbucks.
